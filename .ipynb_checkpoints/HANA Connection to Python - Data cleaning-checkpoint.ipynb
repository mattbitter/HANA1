# %%
import pyhdb
import pandas as pd
import sqlalchemy

# %%
from sqlalchemy import create_engine

# %%
#load tables into hana and then into DF
#tables are T_LFT, T_MT then into T_TFT

connection = connection = pyhdb.connect(
    host="localhost",
    port=30015,
    user="SYSTEM",
    password="#####"
)

# %%
engine = create_engine('hana://SYSTEM:######@localhost:30015')

# %%
#cursor = connection.cursor()
#cursor.execute("SELECT * FROM SYSTEM.T_MT order by SR")
#T_MT = pd.DataFrame(cursor.fetchall())

# %%
T_MT = pd.read_sql_query("SELECT * FROM SYSTEM.T_MT order by SR",connection)

# %%
T_MT[:5]
# Out:
#    SR       RANK NORMALIZED_TERM
# 0   1  17.196979     productions
# 1   1  17.196979          layout
# 2   1  17.196979       including
# 3   1  17.196979          2008r2
# 4   1  15.357480           media

# %%
#cursorTFT = connection.cursor()
#cursorTFT.execute("SELECT * FROM SYSTEM.T_TFT order by SR")
#T_TFT = pd.DataFrame(cursorTFT.fetchall())
T_TFT = pd.read_sql_query("SELECT * FROM SYSTEM.T_TFT order by SR",connection)

# %%
T_TFT = T_TFT.set_index('SR')
#T_TFT.reset_index()

# %%
T_TFT[600:700]
# Out:
#        F1    F2    F3    F4    F5    F6    F7    F8    F9   F10  ...  F2655  \
# SR                                                               ...
# 601  None  None  None  None  None  None  None  None  None  None  ...   None
# 602  None  None  None  None  None  None  None  None  None  None  ...   None
# 603  None  None  None  None  None  None  None  None  None  None  ...   None
# 604  None  None  None  None  None  None  None  None  None  None  ...   None
# 605  None  None  None  None  None  None  None  None  None  None  ...   None
# 606  None  None  None  None  None  None  None  None  None  None  ...   None
# 607  None  None  None  None  None  None  None  None  None  None  ...   None
# 608  None  None  None  None  None  None  None  None  None  None  ...   None
# 609  None  None  None  None  None  None  None  None  None  None  ...   None
# 610  None  None  None  None  None  None  None  None  None  None  ...   None
# ...

# %%
#cursorLFT = connection.cursor()
#cursorLFT.execute("SELECT * FROM SYSTEM.T_LFT order by F")
#T_LFT = pd.DataFrame(cursorLFT.fetchall())
T_LFT = pd.read_sql_query("SELECT * FROM SYSTEM.T_LFT order by F",connection)

# %%
T_LFT[:15]
# Out:
#        F NORMALIZED_TERM
# 0      1          server
# 1     10   cabra4meswfd5
# 2    100          budget
# 3   1000          device
# 4   1001          bitmap
# 5   1002          dolcic
# 6   1003             pid
# 7   1004             ole
# 8   1005        document
# 9   1006       payloadid
# 10  1007     copyreceipt
# 11  1008    po4500006365
# 12  1009           idocs
# 13   101              la
# 14  1010     directoryit

# %%
for row in T_MT.itertuples():
    #v_fc = 'F'+str(row[1:2])
    v_fr = ''.join(map(str,row[1:2]))
    v_fr = int(v_fr)
    v_fc = T_LFT[T_LFT['NORMALIZED_TERM'] == ''.join(map(str,row[3:4]))].head()
    v_fc = 'F'+v_fc[['F']]
    v_fc = ''.join(map(str,v_fc.iloc[0]))
    v_value = ''.join(map(str,row[2:3]))
    T_TFT.set_value(v_fr, v_fc, v_value)
    #print (v_fr,''.join(map(str,row[3:4])),v_fc,v_value)
    #T_TFT.iloc[v_fr, T_TFT.columns.get_loc(v_fc)] = v_value
    
    #T_TFT[v_fr,v_fc] = v_value

# %%
T_TFT = T_TFT.reset_index()

# %%
T_TFT.to_sql(name='T_TFT2', con=engine, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# C:\Users\Splinta\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1181                         parameters,
# -> 1182                         context)
#    1183         except BaseException as e:
#
# C:\Users\Splinta\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     469     def do_execute(self, cursor, statement, parameters, context=None):
# --> 470         cursor.execute(statement, parameters)
#     471
#
# C:\Users\Splinta\Anaconda3\lib\site-packages\pyhdb\cursor.py in execute(self, statement, parameters)
#     257             # Directly execute the statement, nothing else to prepare:
# --> 258             self._execute_direct(statement)
#     259         else:
#
# ...

# %%
T_TFT[-3:]
# Out:
#       SR    F1    F2    F3    F4    F5    F6    F7    F8    F9      ...        \
# 734  735  None  None  None  None  None  None  None  None  None      ...
# 735  736  None  None  None  None  None  None  None  None  None      ...
# 736  737  None  None  None  None  None  None  None  None  None      ...
#
#     F2655 F2656 F2657 F2658 F2659 F2660          F2661          F2662  \
# 734  None  None  None  None  None  None           None           None
# 735  None  None  None  None  None  None           None           None
# 736  None  None  None  None  None  None  44.1410097633  44.1410097633
#
#              F2663          F2664
# 734           None           None
# 735           None           None
# 736  44.1410097633  44.1410097633
#
# [3 rows x 2665 columns]

# %%
#T_TFT.to_csv('T_TFT.csv', sep=',')
